# %%
import numpy as np

test = np.load("/Users/nicolasoulianov/mistral/observation.npy")

# %%
# Use imshow to display the image
import matplotlib.pyplot as plt

plt.imshow(test[100:200, :])

# %%
frame = test[165:200, 280:]
plt.imshow(frame)

# %%
frame
# Out:
# array([[[ 88, 176,  40],
#         [ 88, 176,  40],
#         [ 88, 176,  40],
#         ...,
#         [ 56, 104, 160],
#         [ 48,  80, 136],
#         [ 48,  88, 152]],
#
#        [[ 88, 176,  40],
#         [ 88, 176,  40],
#         [ 88, 176,  40],
#         ...,
#         [ 48,  88, 152],
#         [ 48,  80, 136],
#         [ 48,  80, 136]],
#
#        [[ 88, 176,  40],
#         [ 88, 176,  40],
#         [ 88, 176,  40],
#         ...,
#         [ 48,  88, 152],
#         [ 48,  80, 136],
#         [ 48,  80, 136]],
#
#        ...,
#
#        [[248, 184, 128],
#         [248, 184, 128],
#         [248, 184, 128],
#         ...,
#         [240, 216, 184],
#         [240, 216, 184],
#         [240, 216, 184]],
#
#        [[248, 184, 128],
#         [248, 152,  96],
#         [248, 152,  96],
#         ...,
#         [248, 224, 160],
#         [248, 224, 160],
#         [248, 224, 160]],
#
#        [[208, 120,  72],
#         [248, 184, 128],
#         [248, 184, 128],
#         ...,
#         [248, 232, 168],
#         [248, 232, 168],
#         [248, 232, 168]]], dtype=uint8)

# %%
np.linalg.norm
# Out:
# array([[[ 75,  87, 182],
#         [179,   1,  78],
#         [195,  17,  62],
#         ...,
#         [115, 127, 174],
#         [123, 103, 150],
#         [179,  31, 102]],
#
#        [[187,   1,  54],
#         [195,  17,  62],
#         [107,  63, 158],
#         ...,
#         [123, 103, 150],
#         [123, 103, 150],
#         [179,  39, 118]],
#
#        [[211,  17,  38],
#         [107,  63, 158],
#         [ 75,  87, 182],
#         ...,
#         [123, 103, 150],
#         [155,  79, 150],
#         [163,  63, 134]],
#
#        ...,
#
#        [[ 19, 151, 150],
#         [  3, 159, 150],
#         [ 19, 151, 150],
#         ...,
#         [ 13, 167, 150],
#         [ 13, 167, 150],
#         [ 13, 167, 150]],
#
#        [[  3, 159, 150],
#         [  3, 159, 150],
#         [  3, 159, 150],
#         ...,
#         [ 21, 175, 126],
#         [ 21, 175, 126],
#         [ 21, 175, 126]],
#
#        [[  3, 159, 150],
#         [ 13, 167, 150],
#         [  3, 159, 150],
#         ...,
#         [ 21, 183, 134],
#         [ 21, 183, 134],
#         [ 21, 183, 134]]])

# %%
plt.imshow(diff)

# %%
diff.min()
# Out:
# 0.0

# %%
KEN_RED = [248, 0, 0]
KEN_GREEN = [48, 88, 152]


color = np.array(KEN_GREEN)

frame = test[ 80:200,:]

# Detect the red color of Ken
# !!! THIS DOESNT WORK BECAUSE THE COLOR ISNT RIGHT!!

diff = np.linalg.norm(np.array(frame) - np.array(color), axis=2)
# print("diff", diff)
mask = diff < 1

# Return the index where the red color is detected
coordinates = mask.nonzero()
# print("coordinates", coordinates)

# Add back the vertical offset
first_match = (coordinates[1][0], coordinates[0][0] + 80)

print("first_match", first_match)
# Out:
# first_match (383, 81)

# %%
test.shape
# Out:
# (2, 6, 3)

# %%
# find where color is [64, 80, 144]

mask = test == [64, 80, 144]
# mask.any(axis=2)

coordinates = mask.any(axis=2).nonzero()

coordinates[0][0], coordinates[1][0]
# Out:
# (0, 0)

# %%
mask.any(axis=2)
# Out:
# array([[ True,  True,  True, False, False, False],
#        [False,  True,  True, False, False, False]])
